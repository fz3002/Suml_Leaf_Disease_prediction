# %%
from src.model.model import *

# %%
# Tworzymy instancje modelu
model = SqueezeNet(num_classes=8)

# %%
# Cała Architektura modelu
print(model)
# Out:
# SqueezeNet(
#   (features): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(7, 7), stride=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (3): FireBlock(
#       (squeeze): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand_activation): ReLU(inplace=True)
#     )
#     (4): FireBlock(
#       (squeeze): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand_activation): ReLU(inplace=True)
#     )
#     (5): FireBlock(
# ...

# %%
# Info o liczbie parametrów i ile waży
model.print_info()
# Out:
# ===== SqueezeNet Model Info =====
# Total parameters:      739,528
# Trainable parameters: 739,528
# ---------------------------------
# Parameters memory: 2.82 MB
# Gradients memory:  0.00 MB
# Buffers memory:    0.00 MB
# ---------------------------------
# Total memory:      2.82 MB
# ...

# %%
# Przykład użycia
dummy_input = torch.randn(1, 3, 224, 224)

model_output = model(dummy_input)

print(model_output)
# Out:
# tensor([[ 0.6982,  0.0765, -0.0084, -0.3830, -0.1215,  0.5558, -0.4668, -0.4802]],
#        grad_fn=<ViewBackward0>)

# %%
from data_preparation.preprocessing.data_util import *

# %%
download_dataset()
# Out:
# [INFO] download_dataset() - Downloading Dataset  /home/michal/.cache/kagglehub/datasets/warcoder/mango-leaf-disease-dataset/versions/1
# [INFO] download_dataset() - Destination path already exists
# [INFO] download_dataset() - Deleting destination path
# [INFO] download_dataset() - Saved dataset to:  /home/michal/PycharmProjects/Suml_Leaf_Disease_prediction/data/1_raw
# None

# %%
split_dataset('split')
# Out:
# Split dataset : 100%|██████████| 8/8 [00:00<00:00, 62.26it/s]

# %%
split_dataset('processed')
# Out:
# Split dataset : 100%|██████████| 8/8 [00:00<00:00, 64.33it/s]

# %%
from data_preparation.preprocessing.preprocessing import preprocess_images

preprocess_images()
# Out:
# [INFO] Preprocessing zakończony dla folderu: /home/michal/PycharmProjects/Suml_Leaf_Disease_prediction/data/3_processed/train/Healthy
# [INFO] Preprocessing zakończony dla folderu: /home/michal/PycharmProjects/Suml_Leaf_Disease_prediction/data/3_processed/train/Die Back
# [INFO] Preprocessing zakończony dla folderu: /home/michal/PycharmProjects/Suml_Leaf_Disease_prediction/data/3_processed/train/Bacterial Canker
# [INFO] Preprocessing zakończony dla folderu: /home/michal/PycharmProjects/Suml_Leaf_Disease_prediction/data/3_processed/train/Sooty Mould
# [INFO] Preprocessing zakończony dla folderu: /home/michal/PycharmProjects/Suml_Leaf_Disease_prediction/data/3_processed/train/Powdery Mildew
# [INFO] Preprocessing zakończony dla folderu: /home/michal/PycharmProjects/Suml_Leaf_Disease_prediction/data/3_processed/train/Gall Midge
# [INFO] Preprocessing zakończony dla folderu: /home/michal/PycharmProjects/Suml_Leaf_Disease_prediction/data/3_processed/train/Anthracnose
# ...

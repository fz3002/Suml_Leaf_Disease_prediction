# %%
from src.data_preparation.preprocessing.data_util import load_config_file
from src.utils.plot_graphs import *

# %%
metrics = load_metrics(r"C:\Users\Michał\PycharmProjects\SUML\data\4_weights\final\metrics")

# %%
palette = {
        "train": "#264653",  # ciemny granat
        "val": "#e76f51",  # ciepły czerwono-pomarańczowy
    }

# %%
metric = "loss"
m = {
        "epoch": metrics["epoch"],
        "train": metrics[f"train_{metric}"],
        "val": metrics[f"val_{metric}"]
    }
plot(title=f"Train vs. Val {metric}",
         name=metric,
         values=m,
         palette=palette)

# %%
metric = "accuracy"
m = {
        "epoch": metrics["epoch"],
        "train": metrics[f"train_{metric}"],
        "val": metrics[f"val_{metric}"]
    }
plot(title=f"Train vs. Val {metric}",
         name=metric,
         values=m,
         palette=palette)

# %%
metric = "recall"
m = {
        "epoch": metrics["epoch"],
        "train": metrics[f"train_{metric}"],
        "val": metrics[f"val_{metric}"]
    }
plot(title=f"Train vs. Val {metric}",
         name=metric,
         values=m,
         palette=palette)

# %%
metric = "precision"
m = {
        "epoch": metrics["epoch"],
        "train": metrics[f"train_{metric}"],
        "val": metrics[f"val_{metric}"]
    }
plot(title=f"Train vs. Val {metric}",
         name=metric,
         values=m,
         palette=palette)

# %%
metric = "f1"
m = {
        "epoch": metrics["epoch"],
        "train": metrics[f"train_{metric}"],
        "val": metrics[f"val_{metric}"]
    }
plot(title=f"Train vs. Val {metric}",
         name=metric,
         values=m,
         palette=palette)

# %%
metric = "f1_w"
m = {
        "epoch": metrics["epoch"],
        "train": metrics[f"train_{metric}"],
        "val": metrics[f"val_{metric}"]
    }
plot(title=f"Train vs. Val F1 weighted",
         name=metric,
         values=m,
         palette=palette)

# %%
from src.data_preparation.preprocessing.data_util import load_config_file
from src.process.train import *

# %%
# Najpierw wprowadzić wszystkie parametry do configa i ustawić nazwę treningu

# %%
# Pobieramy configa
config = load_config_file()

# %%
# Ściezka projektu
project_path = config["path"]["project_path"]

# %%
# Ścieżka do wag modelu
model_weights = config["path"]["model_weights"]["root"]

# %%
# Nazwa treningu
run_name = config["train"]["run_name"]

# %%
# Folder gdzie zapiszemy wyniki
output_dir = os.path.join(project_path, model_weights, run_name)

# %%
fit(
    model_section=config["model"], # Info o modelu z configu
    train_section=config["train"], # Info o treningu z configu
    output_dir=str(output_dir) # Scieżka do folderu wyjściowego
)
# Out:
# === Training config ===
# device: cuda
# epochs: 30
# lr: 0.0003
# weight_decay: 0.0005
# scheduler: CosineAnnealingLR (eta_min=5e-07)
# ========================
#
#
# Epoch 01/30 | lr=3.00e-04
# train | loss=1.8049 acc=0.2246 f1=0.1104
# val   | loss=1.5647 acc=0.2862 f1=0.1531
#
# Epoch 02/30 | lr=2.99e-04
# train | loss=1.4888 acc=0.3750 f1=0.2634
# val   | loss=1.2201 acc=0.4836 f1=0.3260
#
# Epoch 03/30 | lr=2.97e-04
# train | loss=1.3341 acc=0.4674 f1=0.3421
# val   | loss=1.1890 acc=0.4556 f1=0.2945
#
# Epoch 04/30 | lr=2.93e-04
# train | loss=1.1777 acc=0.5442 f1=0.4186
# val   | loss=1.1187 acc=0.5214 f1=0.3721
#
# Epoch 05/30 | lr=2.87e-04
# train | loss=1.0865 acc=0.5745 f1=0.4592
# val   | loss=1.0221 acc=0.5938 f1=0.4550
#
# Epoch 06/30 | lr=2.80e-04
# train | loss=0.9795 acc=0.6205 f1=0.5113
# val   | loss=0.8634 acc=0.6464 f1=0.5032
#
# Epoch 07/30 | lr=2.71e-04
# train | loss=0.8442 acc=0.6875 f1=0.5732
# val   | loss=0.6269 acc=0.7763 f1=0.6215
#
# Epoch 08/30 | lr=2.62e-04
# train | loss=0.7494 acc=0.7309 f1=0.6176
# val   | loss=0.6131 acc=0.7878 f1=0.6212
#
# Epoch 09/30 | lr=2.50e-04
# train | loss=0.5833 acc=0.7908 f1=0.6819
# val   | loss=0.3977 acc=0.8421 f1=0.6759
#
# Epoch 10/30 | lr=2.38e-04
# train | loss=0.5719 acc=0.8001 f1=0.6904
# val   | loss=0.3701 acc=0.8668 f1=0.7117
#
# Epoch 11/30 | lr=2.25e-04
# train | loss=0.4990 acc=0.8088 f1=0.7009
# val   | loss=0.3609 acc=0.8766 f1=0.7269
#
# Epoch 12/30 | lr=2.11e-04
# train | loss=0.4335 acc=0.8379 f1=0.7323
# val   | loss=0.2780 acc=0.8882 f1=0.7284
#
# Epoch 13/30 | lr=1.97e-04
# train | loss=0.4060 acc=0.8436 f1=0.7349
# val   | loss=0.2659 acc=0.8898 f1=0.7338
#
# Epoch 14/30 | lr=1.81e-04
# train | loss=0.3680 acc=0.8600 f1=0.7505
# val   | loss=0.2635 acc=0.8964 f1=0.7432
#
# Epoch 15/30 | lr=1.66e-04
# train | loss=0.3188 acc=0.8844 f1=0.7749
# val   | loss=0.1974 acc=0.9161 f1=0.7669
#
# Epoch 16/30 | lr=1.50e-04
# train | loss=0.3157 acc=0.8791 f1=0.7671
# val   | loss=0.2065 acc=0.9128 f1=0.7577
#
# Epoch 17/30 | lr=1.35e-04
# train | loss=0.2551 acc=0.9049 f1=0.7917
# val   | loss=0.2175 acc=0.9260 f1=0.7709
#
# Epoch 18/30 | lr=1.19e-04
# train | loss=0.2295 acc=0.9169 f1=0.8052
# val   | loss=0.2002 acc=0.9243 f1=0.7660
#
# Epoch 19/30 | lr=1.04e-04
# train | loss=0.2175 acc=0.9225 f1=0.8076
# val   | loss=0.1417 acc=0.9490 f1=0.7852
#
# Epoch 20/30 | lr=8.93e-05
# train | loss=0.1849 acc=0.9330 f1=0.8190
# val   | loss=0.1627 acc=0.9359 f1=0.7774
#
# Epoch 21/30 | lr=7.54e-05
# train | loss=0.1855 acc=0.9345 f1=0.8193
# val   | loss=0.1094 acc=0.9622 f1=0.8021
#
# Epoch 22/30 | lr=6.22e-05
# train | loss=0.1535 acc=0.9431 f1=0.8321
# val   | loss=0.1412 acc=0.9523 f1=0.7993
#
# Epoch 23/30 | lr=5.00e-05
# train | loss=0.1460 acc=0.9513 f1=0.8403
# val   | loss=0.0965 acc=0.9655 f1=0.8141
#
# Epoch 24/30 | lr=3.90e-05
# train | loss=0.1248 acc=0.9506 f1=0.8411
# val   | loss=0.0793 acc=0.9720 f1=0.8183
#
# Epoch 25/30 | lr=2.91e-05
# train | loss=0.1060 acc=0.9641 f1=0.8550
# val   | loss=0.0834 acc=0.9704 f1=0.8169
#
# Epoch 26/30 | lr=2.06e-05
# train | loss=0.0992 acc=0.9652 f1=0.8544
# val   | loss=0.0715 acc=0.9671 f1=0.8105
#
# Epoch 27/30 | lr=1.34e-05
# train | loss=0.0982 acc=0.9667 f1=0.8573
# val   | loss=0.0765 acc=0.9671 f1=0.8152
#
# Epoch 28/30 | lr=7.83e-06
# train | loss=0.0807 acc=0.9738 f1=0.8647
# val   | loss=0.0699 acc=0.9688 f1=0.8156
#
# Epoch 29/30 | lr=3.77e-06
# train | loss=0.0972 acc=0.9689 f1=0.8602
# val   | loss=0.0691 acc=0.9671 f1=0.8154
#
# Epoch 30/30 | lr=1.32e-06
# train | loss=0.0837 acc=0.9678 f1=0.8572
# val   | loss=0.0650 acc=0.9688 f1=0.8191
